# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data_hiv.csv')

# %%
df.head()
# Out:
#        IndicatorCode                     Indicator ValueType  \
# 0     HIV_0000000026  Number of new HIV infections   numeric
# 1     HIV_0000000026  Number of new HIV infections   numeric
# 2     HIV_0000000026  Number of new HIV infections   numeric
# 3     HIV_0000000026  Number of new HIV infections   numeric
# 4     HIV_0000000026  Number of new HIV infections   numeric
# ...              ...                           ...       ...
# 4651  HIV_0000000026  Number of new HIV infections   numeric
# 4652  HIV_0000000026  Number of new HIV infections   numeric
# 4653  HIV_0000000026  Number of new HIV infections   numeric
# 4654  HIV_0000000026  Number of new HIV infections   numeric
# 4655  HIV_0000000026  Number of new HIV infections   numeric
#
#      ParentLocationCode         ParentLocation Location type  \
# 0                   AMR               Americas       Country
# 1                   AFR                 Africa       Country
# 2                   EUR                 Europe       Country
# 3                   EUR                 Europe       Country
# 4                   EUR                 Europe       Country
# ...                 ...                    ...           ...
# 4651                EMR  Eastern Mediterranean       Country
# 4652                EUR                 Europe       Country
# 4653                AMR               Americas       Country
# 4654                EUR                 Europe       Country
# 4655                WPR        Western Pacific       Country
#
#      SpatialDimValueCode                                           Location  \
# 0                    BRB                                           Barbados
# 1                    COM                                            Comoros
# 2                    HRV                                            Croatia
# 3                    DNK                                            Denmark
# 4                    ISL                                            Iceland
# ...                  ...                                                ...
# 4651                 ARE                               United Arab Emirates
# 4652                 GBR  United Kingdom of Great Britain and Northern I...
# 4653                 USA                           United States of America
# 4654                 UZB                                         Uzbekistan
# 4655                 VUT                                            Vanuatu
#
#      Period type  Period  ...  FactValueUoM  FactValueNumericLowPrefix  \
# 0           Year    2023  ...           NaN                        NaN
# 1           Year    2023  ...           NaN                        NaN
# 2           Year    2023  ...           NaN                        NaN
# 3           Year    2023  ...           NaN                        NaN
# 4           Year    2023  ...           NaN                        NaN
# ...          ...     ...  ...           ...                        ...
# 4651        Year    2000  ...           NaN                        NaN
# 4652        Year    2000  ...           NaN                        NaN
# 4653        Year    2000  ...           NaN                        NaN
# 4654        Year    2000  ...           NaN                        NaN
# 4655        Year    2000  ...           NaN                        NaN
#
#       FactValueNumericLow  FactValueNumericHighPrefix  FactValueNumericHigh  \
# 0                   100.0                         NaN                 100.0
# 1                   100.0                         NaN                 100.0
# 2                   100.0                         NaN                 100.0
# 3                   100.0                         NaN                 100.0
# 4                   100.0                         NaN                 100.0
# ...                   ...                         ...                   ...
# 4651                  NaN                         NaN                   NaN
# 4652                  NaN                         NaN                   NaN
# 4653                  NaN                         NaN                   NaN
# 4654                  NaN                         NaN                   NaN
# 4655                  NaN                         NaN                   NaN
#
#                    Value  FactValueTranslationID  FactComments  Language  \
# 0     <100 [<100 - <100]                     NaN           NaN        EN
# 1     <100 [<100 - <100]                     NaN           NaN        EN
# 2     <100 [<100 - <100]                     NaN           NaN        EN
# 3     <100 [<100 - <100]                     NaN           NaN        EN
# 4     <100 [<100 - <100]                     NaN           NaN        EN
# ...                  ...                     ...           ...       ...
# 4651             No data                   827.0           NaN        EN
# 4652             No data                   827.0           NaN        EN
# 4653             No data                   827.0           NaN        EN
# 4654             No data                   827.0           NaN        EN
# 4655             No data                   827.0           NaN        EN
#
#                   DateModified
# 0     2024-07-21T23:00:00.000Z
# 1     2024-07-21T23:00:00.000Z
# 2     2024-07-21T23:00:00.000Z
# 3     2024-07-21T23:00:00.000Z
# 4     2024-07-21T23:00:00.000Z
# ...                        ...
# 4651  2024-07-21T23:00:00.000Z
# 4652  2024-07-21T23:00:00.000Z
# 4653  2024-07-21T23:00:00.000Z
# 4654  2024-07-21T23:00:00.000Z
# 4655  2024-07-21T23:00:00.000Z
#
# [4656 rows x 34 columns]

# %%
new_data=df[df['Location']=='South Africa']

# %%
new_data=new_data[['Location','Period','FactValueNumeric','FactValueNumericLow','FactValueNumericHigh']]

# %%
new_data
# Out:
#           Location  Period  FactValueNumeric  FactValueNumericLow  \
# 61    South Africa    2023          150000.0             130000.0
# 255   South Africa    2022          150000.0             140000.0
# 455   South Africa    2021          160000.0             140000.0
# 655   South Africa    2020          170000.0             150000.0
# 845   South Africa    2019          180000.0             160000.0
# 1041  South Africa    2018          190000.0             170000.0
# 1243  South Africa    2017          210000.0             190000.0
# 1446  South Africa    2016          230000.0             200000.0
# 1640  South Africa    2015          250000.0             220000.0
# 1834  South Africa    2014          260000.0             230000.0
# 2032  South Africa    2013          270000.0             250000.0
# 2225  South Africa    2012          290000.0             260000.0
# 2419  South Africa    2011          310000.0             280000.0
# 2613  South Africa    2010          340000.0             310000.0
# 2809  South Africa    2009          380000.0             340000.0
# 3007  South Africa    2008          410000.0             370000.0
# 3204  South Africa    2007          440000.0             390000.0
# 3397  South Africa    2006          460000.0             420000.0
# 3595  South Africa    2005          480000.0             440000.0
# 3791  South Africa    2004          500000.0             460000.0
# 3987  South Africa    2003          510000.0             460000.0
# 4182  South Africa    2002          510000.0             470000.0
# 4371  South Africa    2001          520000.0             470000.0
# 4563  South Africa    2000          520000.0             470000.0
#
#       FactValueNumericHigh
# 61                170000.0
# 255               170000.0
# 455               180000.0
# 655               190000.0
# 845               200000.0
# 1041              220000.0
# 1243              230000.0
# 1446              250000.0
# 1640              270000.0
# 1834              290000.0
# 2032              300000.0
# 2225              320000.0
# 2419              350000.0
# 2613              380000.0
# 2809              420000.0
# 3007              460000.0
# 3204              480000.0
# 3397              510000.0
# 3595              530000.0
# 3791              550000.0
# 3987              560000.0
# 4182              560000.0
# 4371              570000.0
# 4563              570000.0

# %%
new_data.to_csv('southafrica_hiv.csv')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(new_data['FactValueNumeric'])
plt.plot(new_data['FactValueNumericLow'])
plt.plot(new_data['FactValueNumericHigh'])
plt.legend(['FactValueNumeric','FactValueNumericLow','FactValueNumericHigh'])

# %%
arv=pd.read_csv('data_ARV.csv')

# %%
arv=arv[['Period','FactValueNumeric']]

# %%
arv
# Out:
#    Period  FactValueNumeric
# 0    2023           5936502
# 1    2022           5792683
# 2    2021           5649819
# 3    2020           5501515
# 4    2015           3682691
# 5    2010           1407392
# 6    2005            166179
# 7    2000              6228

# %%
new_rows = {'Period': [2019,2018,2017,2016,2014,2013,2012,2011,2009,2008,2007,2006,2004,2003,2002,2001], 'FactValueNumeric': [5501515]}

# %%
data = {
    'Year': [2023, 2022, 2021, 2020, 2015, 2010, 2005, 2000],
    'Value': [5936502, 5792683, 5649819, 5501515, 3682691, 1407392, 166179, 6228]
}
df = pd.DataFrame(data)

# Sort the DataFrame by the 'Year' column in ascending order
df = df.sort_values('Year').reset_index(drop=True)

# Create a new DataFrame that includes all years between the minimum and maximum years
full_years = pd.DataFrame({'Year': range(df['Year'].min(), df['Year'].max() + 1)})

# Merge the full range of years with the original data
df_full = pd.merge(full_years, df, on='Year', how='left')

# Fill the missing values using linear interpolation
df_full['Value'] = df_full['Value'].interpolate()

# %%
df_full['Value']=[int(df_full['Value'][i]) for i in range(len(df_full['Value']))]
df_full
# Out:
#     Year    Value
# 0   2000     6228
# 1   2001    38218
# 2   2002    70208
# 3   2003   102198
# 4   2004   134188
# 5   2005   166179
# 6   2006   414421
# 7   2007   662664
# 8   2008   910906
# 9   2009  1159149
# 10  2010  1407392
# 11  2011  1862451
# 12  2012  2317511
# 13  2013  2772571
# 14  2014  3227631
# 15  2015  3682691
# 16  2016  4046455
# 17  2017  4410220
# 18  2018  4773985
# 19  2019  5137750
# 20  2020  5501515
# 21  2021  5649819
# 22  2022  5792683
# 23  2023  5936502

# %%
type(df_full['Value'][0])
# Out:
# numpy.int64

# %%
plt.plot(df_full['Value'])

# %%
infection_data=np.array(new_data['FactValueNumeric'])
infection_data=infection_data[::-1]

# %%
import numpy as np
from scipy.integrate import odeint
from scipy.optimize import minimize

arv_data = np.array(df_full['Value'])
# Modèle SIR avec les autres paramètres
def hiv_model(A, t, beta, alpha1, alpha2, mu, k1, k2, d, lamda, delta1, delta2, sigma):
    i, a, c,t_var, s, r = A
    #t_var=arv_data[int(t)]
    didt = beta * s * t_var + alpha1 * t_var - (d + k1 + k2) * i
    dadt = k1 * i + alpha2 * t_var - (delta1 + d) * a
    dcdt = k2 * i - lamda * c - d * c
    dtdt = lamda * c - alpha1 * t_var - alpha2 * t_var - (delta2 + d) * t_var
    dsdt = sigma - beta * s * i - d * s - mu * s
    drdt = mu * s - d * r
    return [didt, dadt, dcdt,dtdt, dsdt, drdt]

# Données d'infections par an (2000-2023)
years = np.arange(2000, 2024)

# Fonction d'erreur à minimiser
def error(params, initial_conditions, t, data):
    model_output = odeint(hiv_model, initial_conditions, t, args=tuple(params))
    infected_simulated = model_output[:, 0]  # Le premier élément correspond aux infectés
    return np.sum((infected_simulated - data) ** 2)

# Conditions initiales pour [I0, A0, C0, T0, S0, R0]
initial_conditions = [520000, 0, 7000,6228, 46813266, 0]

# Temps (correspond aux années 2000 à 2023)
t = np.arange(0, len(infection_data))

# Estimations initiales des paramètres
initial_params = [0.5, 0.1, 0.1, 0.01, 0.2, 0.2, 0.01, 0.3, 0.01, 0.01, 0.1]

bounds = [(0, None), (0, None), (0, None), (0, None), (0, None), (0, None), (0, None), (0, None), (0, None), (0, None), (0, None)]
# Optimisation pour ajuster les paramètres
result = minimize(error, initial_params, args=(initial_conditions, t, infection_data), method='L-BFGS-B',bounds=bounds)

# Paramètres optimisés
optimal_params = result.x
print("Paramètres optimisés : ", optimal_params)

# Simulation des résultats avec les paramètres optimisés
simulated_results = odeint(hiv_model, initial_conditions, t, args=tuple(optimal_params))

# Visualisation des résultats
import matplotlib.pyplot as plt
plt.plot(years, simulated_results[:, 0], label='Infectés simulés')
plt.plot(years, infection_data, 'o', label='Données réelles')
plt.xlabel('Année')
plt.ylabel('Nombre d\'infectés')
plt.legend()
plt.show()
# Out:
# Paramètres optimisés :  [5.01835774e-01 9.82011749e+00 4.67939255e-02 8.70250045e-03
#  8.63694798e-02 6.71174537e-01 2.52177445e-04 1.46119501e+00
#  1.05292984e-02 0.00000000e+00 1.00220975e-01]

# %%
beta, alpha1, alpha2, mu, k1, k2, d, lamda, delta1, delta2, sigma= optimal_params

# %%
# Temps (jours)
t = np.linspace(0, 50, 1000)


# Résoudre les ODEs
solution = odeint(hiv_model, initial_conditions, t, args=(beta, alpha1, alpha2, mu, k1, k2, d, lamda, delta1, delta2, sigma))
i, a, c, t_val, s, r  = solution.T


# Visualiser les résultats
plt.figure(figsize=(10,6))
#plt.plot(t, s, label="Susceptibles")
plt.plot(t, i, label="Infectés")
plt.plot(t, a, label="Stade Full-blown A")
plt.plot(t, c, label="Conscience (C)")
plt.plot(t, t_val, label="Traitement (T)")
plt.plot(t, r, label="Rétablis")
plt.xlabel("Temps (jours)")
plt.ylabel("Proportions")
plt.legend()
plt.title("Modèle épidémiologique avec traitement et conscience")
plt.show()

# %%
# Temps (jours)
t = np.linspace(0, 50, 1000)


# Résoudre les ODEs
solution = odeint(hiv_model, initial_conditions, t, args=(beta, alpha1, alpha2, mu, k1, k2, d, lamda, delta1, delta2, sigma))
i, a, c, t_val, s, r  = solution.T


# Visualiser les résultats
plt.figure(figsize=(10,6))
#plt.plot(t, s, label="Susceptibles")
plt.plot(t, i, label="Infectés")
plt.plot(t, a, label="Stade Full-blown A")
plt.plot(t, c, label="Conscience (C)")
plt.plot(t, t_val, label="Traitement (T)")
plt.plot(t, r, label="Rétablis")
plt.xlabel("Temps (jours)")
plt.ylabel("Proportions")
plt.legend()
plt.title("Modèle épidémiologique avec traitement et conscience")
plt.show()

# %%
R0=beta/(d+k1+k2)
Re=R0*s*(1-t_val)

# %%
plt.plot(Re)

# %%
k1,k2
# Out:
# (0.08636947981506037, 0.671174536583752)

# %%
R0
# Out:
# 0.662230528821017

# %%
i=np.arange(0,10,0.1)
R0=beta/(d+k1+i)
plt.figure(figsize=(10, 6))
plt.plot(i, R0, label='R0 en fonction de k2', color='b')
plt.xlabel('k2')
plt.ylabel('R0')
plt.title('Variation de R0 en fonction de k2')
plt.axhline(1, color='r', linestyle='--', label='R0 = 1')
plt.legend()
plt.grid()
plt.show()
